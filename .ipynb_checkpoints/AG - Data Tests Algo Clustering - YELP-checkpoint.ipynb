# %%
import pandas as pd
import matplotlib.pyplot as plt

import re

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.probability import FreqDist

from data_preprocesser import preprocessed_data_path

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.read_csv(preprocessed_data_path + 'categories_30000/yelp_academic_dataset_review_Auto Repair.csv')
df.head()
# Out:
#                 review_id             business_id  stars_x  stars_y  \
# 0  JN0tmjiksWfr4i2NIFuPXw  pLZ9oZM8c6MNbRlg06lBPg        1      3.0
# 1  lFmz61DNRzBPnrwH_cF42g  J0KZR0DDnvj73D-xmbh4uA        4      4.0
# 2  R9p3ug8zNPvawYX_jsO0UA  Tknj3u-3CZTI-q52saTAIA        1      1.0
# 3  FMXER_6R6URYBpV6TYPn9A  rV1nkTx58v_q7YGDkGzfxQ        5      5.0
# 4  bJN2ZPa0jF4xgR1gPKZP3A  hCXknMQalY1QQZrdZGuBHg        3      3.5
#
#          date       city                                               text  \
# 0  2016-08-03  Las Vegas  THEY SELL WRECKED VEHICLES! \nI purchased a 20...
# 1  2017-06-15  Las Vegas  I stopped in here recently as I had to buy a t...
# 2  2012-09-12    Toronto  If you want the "I don't give a shit " attitud...
# 3  2016-06-10  Las Vegas  where to start...\na few months ago I slammed....
# 4  2017-01-24  Las Vegas  I have mixed feelings here. I recently purchas...
#
#                                           categories
# 0  Auto Repair;Car Dealers;Automotive;Auto Parts ...
# 1       Auto Parts & Supplies;Auto Repair;Automotive
# 2                 Car Dealers;Auto Repair;Automotive
# 3                             Auto Repair;Automotive
# 4                 Car Dealers;Auto Repair;Automotive

# %%
# Processing Functions
def identify_tokens(row):
    review = row['text']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    # token_words = [re.sub("[^\w\s]", " ", w) for w in tokens]
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['words']
    meaningful_words = [w for w in my_list if not w in stops and w != " "]
    return (meaningful_words)

stemming = PorterStemmer()

def stem_list(row):
    my_list = row['words_meaningful']
    stemmed_list = [stemming.stem(word) for word in my_list]
    return (stemmed_list)

lemming = WordNetLemmatizer()

def lem_list(row):
    my_list = row['words_non_stop']
    lemmed_list = [lemming.lemmatize(word) for word in my_list]
    return (lemmed_list)

def rejoin_words(row):
    my_list = row['words_meaningful']
    joined_words = ( " ".join(my_list))
    return joined_words

# %%
def process(data_df):
    data_df['text'] = data_df['text'].str.lower()
    data_df['words'] = data_df.apply(identify_tokens, axis=1)
    data_df['words_non_stop'] = data_df.apply(remove_stops, axis=1)
    data_df['words_meaningful'] = data_df.apply(lem_list, axis=1)
    data_df['processed'] = data_df.apply(rejoin_words, axis=1)
    return data_df

# %%
df_processed = process(df)

# %%
df_processed
# Out:
#                     review_id             business_id  stars_x  stars_y  \
# 0      JN0tmjiksWfr4i2NIFuPXw  pLZ9oZM8c6MNbRlg06lBPg        1      3.0
# 1      lFmz61DNRzBPnrwH_cF42g  J0KZR0DDnvj73D-xmbh4uA        4      4.0
# 2      R9p3ug8zNPvawYX_jsO0UA  Tknj3u-3CZTI-q52saTAIA        1      1.0
# 3      FMXER_6R6URYBpV6TYPn9A  rV1nkTx58v_q7YGDkGzfxQ        5      5.0
# 4      bJN2ZPa0jF4xgR1gPKZP3A  hCXknMQalY1QQZrdZGuBHg        3      3.5
# ...                       ...                     ...      ...      ...
# 29995  SvuO9h27-hNb7KF4myNgxA  ZDt9V3Gi5OcCKSCt8HfQEQ        5      4.5
# 29996  5h4Jrp6_rCj7ZoEUTI4Riw  Q-DTuTRgj2THf-AzMc9u9A        5      2.0
# 29997  N0JArwLw_WWu5d4N9RtUCw  gduF_xvjhFCi8-gPyqCcfw        5      3.0
# 29998  xwnsYaWES1UhiE-VRpwQmQ  9TdwYArOC7368bErl4wtjA        1      1.5
# 29999  NYtM9lxHdChFUDXsyBo_hA  LZiapN1JLUulrCSHVhrcKA        5      3.0
#
#              date       city  \
# 0      2016-08-03  Las Vegas
# 1      2017-06-15  Las Vegas
# 2      2012-09-12    Toronto
# 3      2016-06-10  Las Vegas
# 4      2017-01-24  Las Vegas
# ...           ...        ...
# 29995  2015-11-02  Las Vegas
# 29996  2014-11-24       Stow
# 29997  2017-03-23      Tempe
# 29998  2013-11-25    Toronto
# 29999  2014-02-03    Toronto
#
#                                                     text  \
# 0      they sell wrecked vehicles! \ni purchased a 20...
# 1      i stopped in here recently as i had to buy a t...
# 2      if you want the "i don't give a shit " attitud...
# 3      where to start...\na few months ago i slammed....
# 4      i have mixed feelings here. i recently purchas...
# ...                                                  ...
# 29995  good place for someone who doesn't know a thin...
# 29996  more than amazing service! i just moved to ohi...
# 29997  today i recently pick up my car after 3 months...
# 29998  complete rip off and takes advantage of regula...
# 29999  just stopped in to get an e-test. no appointme...
#
#                                               categories  \
# 0      Auto Repair;Car Dealers;Automotive;Auto Parts ...
# 1           Auto Parts & Supplies;Auto Repair;Automotive
# 2                     Car Dealers;Auto Repair;Automotive
# 3                                 Auto Repair;Automotive
# 4                     Car Dealers;Auto Repair;Automotive
# ...                                                  ...
# 29995   Automotive;Oil Change Stations;Auto Repair;Tires
# 29996         Oil Change Stations;Automotive;Auto Repair
# 29997   Body Shops;Auto Detailing;Auto Repair;Automotive
# 29998                             Auto Repair;Automotive
# 29999                             Automotive;Auto Repair
#
#                                                    words  \
# 0      [they, sell, wrecked, vehicles, i, purchased, ...
# 1      [i, stopped, in, here, recently, as, i, had, t...
# 2      [if, you, want, the, i, do, give, a, shit, att...
# 3      [where, to, start, a, few, months, ago, i, tru...
# 4      [i, have, mixed, feelings, here, i, recently, ...
# ...                                                  ...
# 29995  [good, place, for, someone, who, does, know, a...
# 29996  [more, than, amazing, service, i, just, moved,...
# 29997  [today, i, recently, pick, up, my, car, after,...
# 29998  [complete, rip, off, and, takes, advantage, of...
# 29999  [just, stopped, in, to, get, an, no, appointme...
#
#                                           words_non_stop  \
# 0      [sell, wrecked, vehicles, purchased, nissan, a...
# 1      [stopped, recently, buy, torque, wrench, staff...
# 2      [want, give, shit, attitude, service, dept, st...
# 3      [start, months, ago, truck, curb, destroyed, w...
# 4      [mixed, feelings, recently, purchased, xj, one...
# ...                                                  ...
# 29995  [good, place, someone, know, thing, tires, mar...
# 29996  [amazing, service, moved, ohio, car, prepared,...
# 29997  [today, recently, pick, car, months, legends, ...
# 29998  [complete, rip, takes, advantage, regular, cus...
# 29999  [stopped, get, appointment, needed, quick, rea...
#
#                                         words_meaningful  \
# 0      [sell, wrecked, vehicle, purchased, nissan, al...
# 1      [stopped, recently, buy, torque, wrench, staff...
# 2      [want, give, shit, attitude, service, dept, st...
# 3      [start, month, ago, truck, curb, destroyed, wh...
# 4      [mixed, feeling, recently, purchased, xj, one,...
# ...                                                  ...
# 29995  [good, place, someone, know, thing, tire, mark...
# 29996  [amazing, service, moved, ohio, car, prepared,...
# 29997  [today, recently, pick, car, month, legend, se...
# 29998  [complete, rip, take, advantage, regular, cust...
# 29999  [stopped, get, appointment, needed, quick, rea...
#
#                                                processed
# 0      sell wrecked vehicle purchased nissan altima m...
# 1      stopped recently buy torque wrench staff pleas...
# 2      want give shit attitude service dept staff tak...
# 3      start month ago truck curb destroyed wheel rim...
# 4      mixed feeling recently purchased xj one great ...
# ...                                                  ...
# 29995  good place someone know thing tire mark helpfu...
# 29996  amazing service moved ohio car prepared integr...
# 29997  today recently pick car month legend seems lit...
# 29998  complete rip take advantage regular customer g...
# 29999  stopped get appointment needed quick reasonabl...
#
# [30000 rows x 12 columns]

# %%
text = " ".join(review for review in df['processed'])
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 11509080 words in the combination of all review.

# %%
# Generate a word cloud image
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Word2Vec

# %%
from gensim.models import Word2Vec

# %% [markdown]
# ## Etude de la window size : min_count = 1

# %%
window_list = [i for i in range(1,10)]
word = 'car'

df = pd.DataFrame()

for window in window_list:
    model = Word2Vec(df_processed['words_meaningful'], min_count=1, size= 50, workers=3, window=window) 
    for i in range(10):
        similar_word = model.most_similar(word)[i][0]
        similar_word_coeff = round(model.most_similar(word)[i][1], 2)
        df.at[str(i), str(window) + ' words'] = similar_word + ' : ' + str(similar_word_coeff)
    
print(df)
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
#            1 words            2 words             3 words          4 words  \
# 0   vehicle : 0.92     vehicle : 0.92       vehicle : 0.9   vehicle : 0.89
# 1     truck : 0.89       truck : 0.89        truck : 0.86     truck : 0.83
# 2      jeep : 0.82        jeep : 0.74         jeep : 0.63      jeep : 0.57
# 3       suv : 0.78         van : 0.72          van : 0.62       suv : 0.56
# 4       van : 0.77         suv : 0.68          yet : 0.58       van : 0.54
# 5      baby : 0.77        baby : 0.64     loctaion : 0.57   husband : 0.52
# 6  corvette : 0.76  powerstroke : 0.6     actually : 0.57  actually : 0.52
# 7    camaro : 0.74     actually : 0.6          suv : 0.57   washout : 0.52
# 8      bike : 0.72      course : 0.59      planned : 0.56       yet : 0.51
# 9       rig : 0.71     planned : 0.58  powerstroke : 0.55       home : 0.5
#
#            5 words                                  6 words  \
# 0   vehicle : 0.88                           vehicle : 0.84
# 1     truck : 0.77                             truck : 0.78
# 2       van : 0.54                               suv : 0.54
# 3       suv : 0.54                               van : 0.53
# 4      jeep : 0.52                          stealthy : 0.49
# 5  loctaion : 0.51  goingtobuyasubarujustonprinciple : 0.48
# 6     ended : 0.51                              home : 0.48
# 7       home : 0.5                         islington : 0.48
# 8    husband : 0.5                           husband : 0.48
# 9     vehile : 0.5                               yet : 0.48
#
#              7 words          8 words             9 words
# 0     vehicle : 0.83   vehicle : 0.81      vehicle : 0.79
# 1       truck : 0.73     truck : 0.66         truck : 0.6
# 2       since : 0.55  actually : 0.53    paticular : 0.53
# 3          van : 0.5       van : 0.49   snickering : 0.49
# 4  awkwardness : 0.5   washout : 0.49         knpr : 0.48
# 5    maryvale : 0.49   husband : 0.49        eeded : 0.48
# 6         suv : 0.49     since : 0.49         home : 0.47
# 7       trudy : 0.48     ended : 0.47   kostopulos : 0.47
# 8    turnback : 0.48    couple : 0.46      mecanic : 0.47
# 9   something : 0.48        ry : 0.46  fiechtinger : 0.47

# %% [markdown]
# ## Etude de la window size : min_count = 10

# %%
window_list = [i for i in range(1,10)]
word = 'car'

df = pd.DataFrame()

for window in window_list:
    model = Word2Vec(df_processed['words_meaningful'], min_count=10, size= 50, workers=3, window=window) 
    for i in range(10):
        similar_word = model.most_similar(word)[i][0]
        similar_word_coeff = round(model.most_similar(word)[i][1], 2)
        df.at[str(i), str(window) + ' words'] = similar_word + ' : ' + str(similar_word_coeff)
    
print(df)
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
#           1 words          2 words         3 words           4 words  \
# 0  vehicle : 0.91    vehicle : 0.9  vehicle : 0.88    vehicle : 0.87
# 1    truck : 0.86     truck : 0.84    truck : 0.81      truck : 0.81
# 2     jeep : 0.76       jeep : 0.7     jeep : 0.62        suv : 0.57
# 3      suv : 0.72       suv : 0.66       suv : 0.6        van : 0.56
# 4  corvette : 0.7       van : 0.65      van : 0.58       jeep : 0.55
# 5      van : 0.69      baby : 0.57    since : 0.47        bmw : 0.43
# 6     baby : 0.66  corvette : 0.55      bmw : 0.46       home : 0.43
# 7      jaw : 0.65        bmw : 0.5     baby : 0.44   thinking : 0.43
# 8  minivan : 0.63      bike : 0.49     home : 0.44  something : 0.42
# 9     bike : 0.62    sooner : 0.49      yet : 0.42   actually : 0.41
#
#             5 words           6 words           7 words           8 words  \
# 0    vehicle : 0.83    vehicle : 0.81    vehicle : 0.78    vehicle : 0.77
# 1      truck : 0.76      truck : 0.69      truck : 0.63       truck : 0.7
# 2        van : 0.51       jeep : 0.46        van : 0.44        suv : 0.49
# 3        suv : 0.49        van : 0.46  something : 0.43       home : 0.46
# 4       jeep : 0.48        suv : 0.44       home : 0.42        van : 0.44
# 5    husband : 0.43      since : 0.42       jeep : 0.42  something : 0.43
# 6    actually : 0.4  something : 0.41    husband : 0.41       ride : 0.42
# 7  expecting : 0.39     husband : 0.4         suv : 0.4    husband : 0.38
# 8      ended : 0.39         yet : 0.4      couple : 0.4     errand : 0.38
# 9       home : 0.39        home : 0.4      since : 0.39      ended : 0.36
#
#             9 words
# 0    vehicle : 0.77
# 1      truck : 0.55
# 2        van : 0.44
# 3        suv : 0.41
# 4       home : 0.41
# 5        jeep : 0.4
# 6  something : 0.39
# 7      ended : 0.39
# 8      since : 0.38
# 9     couple : 0.38

# %% [markdown]
# ## Etude de la size : min_count = 10, window = 3

# %%
size_list = [10, 50, 100]
word = 'car'

df = pd.DataFrame()

for size in size_list:
    model = Word2Vec(df_processed['words_meaningful'], min_count=10, size= size, workers=3, window=3) 
    for i in range(10):
        similar_word = model.most_similar(word)[i][0]
        similar_word_coeff = round(model.most_similar(word)[i][1], 2)
        df.at[str(i), str(size) + ' words'] = similar_word + ' : ' + str(similar_word_coeff)
    
print(df)
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
#          10 words           50 words          100 words
# 0      mom : 0.91     vehicle : 0.87     vehicle : 0.86
# 1  distance : 0.9       truck : 0.82       truck : 0.76
# 2      trip : 0.9        jeep : 0.61        jeep : 0.59
# 3     home : 0.89         suv : 0.58         suv : 0.55
# 4  vehicle : 0.87         van : 0.58         van : 0.54
# 5   safely : 0.87        home : 0.47         bmw : 0.42
# 6      bus : 0.85         bmw : 0.45          yet : 0.4
# 7     look : 0.84       since : 0.44        baby : 0.39
# 8     away : 0.82        baby : 0.43  girlfriend : 0.37
# 9    block : 0.81  girlfriend : 0.43     husband : 0.37

# %% [markdown]
# ## Word2vec

# %%
w2v = Word2Vec(df_processed['words_meaningful'], min_count=10, size= 50, workers=3, window=3)

# %%
X = w2v[model.wv.vocab]
X.shape
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (6756, 50)

# %%
w2v.most_similar('car')[:10]
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('vehicle', 0.8937708139419556),
#  ('truck', 0.8519301414489746),
#  ('jeep', 0.604089081287384),
#  ('van', 0.6018075346946716),
#  ('suv', 0.5937435626983643),
#  ('bmw', 0.4776960611343384),
#  ('wife', 0.44510769844055176),
#  ('home', 0.43599772453308105),
#  ('baby', 0.43370670080184937),
#  ('something', 0.43340301513671875)]

# %%
from sklearn.decomposition import PCA 

pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
# create a scatter plot of the projection
plt.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)[:50]
plt.show()

# %% [markdown]
# # Glove

# %%
from glove import Corpus, Glove

# %%
# creating a corpus object
corpus = Corpus() 
#training the corpus to generate the co occurence matrix which is used in GloVe
corpus.fit(df_processed['words_meaningful'].tolist(), window=10)
#creating a Glove object which will use the matrix created in the above lines to create embeddings
#We can set the learning rate as it uses Gradient Descent and number of components
glove = Glove(no_components=50, learning_rate=0.001)
 
glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
# Out:
# Performing 30 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
glove.most_similar('tire')
# Out:
# [('guy', 0.9992501587639376),
#  ('thing', 0.9992455910149266),
#  ('one', 0.9992237808865678),
#  ('time', 0.9992117115499954)]

# %%
glove.most_similar('car')
# Out:
# [('service', 0.9994020455234436),
#  ('dealership', 0.9992852160506818),
#  ('time', 0.9992754026445235),
#  ('go', 0.999238349969895)]

# %%
glove.most_similar('price')
# Out:
# [('new', 0.9992888742722004),
#  ('place', 0.9992375958786768),
#  ('back', 0.9992130927588576),
#  ('also', 0.9992104678478692)]

# %% [markdown]
# # TF IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = tfidf_vect.fit_transform(df_processed['processed'].values.astype('U'))

# %%
#https://www.kaggle.com/jbencina/clustering-documents-with-tfidf-and-kmeans

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn import metrics

def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    # Sum of squared errors
    sse = []
    silhouette = []
    for k in iters:            
        mkmeans = MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20).fit(data)
        sse.append(mkmeans.inertia_)
        silhouette.append(metrics.silhouette_score(data, mkmeans.labels_, metric='euclidean'))
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='bo')
    ax.plot(iters, silhouette, marker='ro')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(doc_term_matrix, 20)
# Out:
# Fit 2 clusters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-dbd0c366801f> in <module>
#      22     ax.set_title('SSE by Cluster Center Plot')
#      23
# ---> 24 find_optimal_clusters(doc_term_matrix, 20)
#
# <ipython-input-16-dbd0c366801f> in find_optimal_clusters(data, max_k)
#      11         mkmeans = MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20).fit(data)
#      12         sse.append(mkmeans.inertia_)
# ---> 13         silouhette.append(metrics.silhouette_score(data, mkmeans.labels_, metric='euclidean'))
#      14         print('Fit {} clusters'.format(k))
#      15
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     221                                     labels=labels, label_freqs=label_freqs)
#     222     results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func,
# --> 223                                               **kwds))
#     224     intra_clust_dists, inter_clust_dists = results
#     225     intra_clust_dists = np.concatenate(intra_clust_dists)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1446             X_chunk = X[sl]
#    1447         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1448                                      n_jobs=n_jobs, **kwds)
#    1449         if ((X is Y or Y is None)
#    1450                 and PAIRWISE_DISTANCE_FUNCTIONS.get(metric, None)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1586         func = partial(distance.cdist, metric=metric, **kwds)
#    1587
# -> 1588     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1589
#    1590
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1204
#    1205     if effective_n_jobs(n_jobs) == 1:
# -> 1206         return func(X, Y, **kwds)
#    1207
#    1208     # enforce a threading backend to prevent data communication overhead
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     271     else:
#     272         # if dtype is already float64, no need to chunk and upcast
# --> 273         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     274         distances += XX
#     275         distances += YY
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     135     """
#     136     if sparse.issparse(a) or sparse.issparse(b):
# --> 137         ret = a * b
#     138         if dense_output and hasattr(ret, "toarray"):
#     139             ret = ret.toarray()
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     479             if self.shape[1] != other.shape[0]:
#     480                 raise ValueError('dimension mismatch')
# --> 481             return self._mul_sparse_matrix(other)
#     482
#     483         # If it's a list or whatever, treat it like a matrix
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/sparse/compressed.py in _mul_sparse_matrix(self, other)
#     524            np.asarray(other.indices, dtype=idx_dtype),
#     525            other.data,
# --> 526            indptr, indices, data)
#     527
#     528         return self.__class__((data, indices, indptr), shape=(M, N))
#
# KeyboardInterrupt:

# %%
clusters = MiniBatchKMeans(n_clusters=8, init_size=1024, batch_size=2048, random_state=20).fit_predict(doc_term_matrix)

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.cm as cm


def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=3000, replace=False)
    
    pca = PCA(n_components=2).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(doc_term_matrix, clusters)

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(doc_term_matrix, clusters, tfidf_vect.get_feature_names(), 10)
# Out:
# Cluster 0
# called,told,guy,work,place,truck,car,customer,time,service
#
# Cluster 1
# wanted,price,buy,experience,salesman,deal,vehicle,sale,dealership,car
#
# Cluster 2
# vehicle,best,staff,helpful,highly,car,friendly,experience,recommend,service
#
# Cluster 3
# recommend,place,work,guy,price,customer,car,job,service,great
#
# Cluster 4
# got,place,told,guy,time,flat,car,new,service,tire
#
# Cluster 5
# place,service,price,car,mechanic,auto,work,repair,honest,shop
#
# Cluster 6
# problem,fixed,place,work,day,told,service,took,time,car
#
# Cluster 7
# filter,told,appointment,hour,place,time,car,service,change,oil

# %% [markdown]
# # Word2vec

# %%
w2v = Word2Vec(df_processed['words_meaningful'], min_count=10, size= 50, workers=3, window=3)
X_w2v = w2v[model.wv.vocab]
X_w2v.shape
# Out:
# /home/arthur/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# (6756, 50)

# %%
find_optimal_clusters(X_w2v, 20)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# Fit 8 clusters
# Fit 10 clusters
# Fit 12 clusters
# Fit 14 clusters
# Fit 16 clusters
# Fit 18 clusters
# Fit 20 clusters

# %%
clusters_w2v = MiniBatchKMeans(n_clusters=8, init_size=1024, batch_size=2048, random_state=20).fit_predict(X_w2v)

# %%
def plot_tsne_pca_dense(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=3000, replace=False)
    
    pca = PCA(n_components=2).fit_transform(data[max_items,:])
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(data[max_items,:]))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')

# %%
plot_tsne_pca_dense(X_w2v, clusters_w2v)

# %%
def get_top_keywords_dense(data, clusters, labels, n_terms):
    df = pd.DataFrame(data).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords_dense(X_w2v, clusters_w2v, model.wv.index2word, 10)
# Out:
# Cluster 0
# new,price,like,go,u,day,tire,time,service,shop
#
# Cluster 1
# shop,go,price,know,would,dealership,took,hour,take,service
#
# Cluster 2
# take,got,called,call,took,tire,u,hour,car,back
#
# Cluster 3
# guy,went,year,car,need,recommend,shop,make,called,took
#
# Cluster 4
# tire,guy,car,called,u,work,service,shop,take,took
#
# Cluster 5
# year,went,even,called,make,shop,needed,took,oil,need
#
# Cluster 6
# going,make,guy,part,know,like,go,took,done,recommend
#
# Cluster 7
# could,dealership,make,day,price,done,work,vehicle,get,take

# %% [markdown]
# # Glove

# %%
corpus = Corpus() 
corpus.fit(df_processed['words_meaningful'].tolist(), window=10)
glove = Glove(no_components=50, learning_rate=0.001)

glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
# Out:
# Performing 30 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
find_optimal_clusters(glove.word_vectors, 20)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# Fit 8 clusters
# Fit 10 clusters
# Fit 12 clusters
# Fit 14 clusters
# Fit 16 clusters
# Fit 18 clusters
# Fit 20 clusters

# %%
clusters_glove = MiniBatchKMeans(n_clusters=6, init_size=1024, batch_size=2048, random_state=20).fit_predict(glove.word_vectors)

# %%
plot_tsne_pca_dense(glove.word_vectors, clusters_glove)

# %%
get_top_keywords_dense(glove.word_vectors, clusters_glove, [*glove.dictionary], 10)
# Out:
# Cluster 0
# finally,year,pocket,vehicle,exhaust,warranty,speed,drove,sold,somewhat
#
# Cluster 1
# knowing,found,charged,dealership,high,clue,every,two,began,sell
#
# Cluster 2
# knowing,dealership,charged,found,high,every,clue,two,began,sell
#
# Cluster 3
# manufacturer,dealership,two,charged,found,clue,every,high,began,sell
#
# Cluster 4
# knowing,found,charged,dealership,high,clue,two,every,began,sell
#
# Cluster 5
# process,high,wrecked,problem,vehicle,exhaust,began,somewhat,speed,car

# %% [markdown]
# # Comparaison
